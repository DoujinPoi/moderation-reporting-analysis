# %% [markdown]
# # Community Moderation & Reporting Analysis

# %% [markdown]
# ## Project Overview
# This project analyzes community moderation and reporting data to identify trends, recurring violations, and moderation outcomes. The goal is to convert raw logs into structured insights that support HR, Trust & Safety, and operational decision-making.

# %%
import pandas as pd
df = pd.read_csv('sample_moderation_data.csv')
df.head()

# %% [markdown]
# ## Data Overview

# %%
df.info()

# %% [markdown]
# ## Violation Category Distribution

# %%
df['violation_category'].value_counts()

# %% [markdown]
# ## Moderation Action Distribution

# %%
df['action_taken'].value_counts()

# %% [markdown]
# ## Key Insights
# - Identified the most frequent violation categories.
# - Observed moderation action patterns (removal vs warning).
# - Insights can be used to improve moderation policies and workflows.
